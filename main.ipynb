# %%
import pandas as pd
import numpy as np
import pprint as pp
import pgeocode as pg
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression, ElasticNet, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from scipy.stats import uniform, randint
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from sklearn.model_selection import train_test_split
import warnings
import datetime
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data.csv')
data.drop(['Unnamed: 32'], axis=1, inplace=True)
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean
# 0    842302         M        17.99         10.38          122.80     1001.0  \
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# 0          0.11840           0.27760          0.3001              0.14710  \
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Comprobación de duplicados
existen_duplicados = data.duplicated().any()
if existen_duplicados:
    print("Existen datos duplicados en el DataFrame.")
else:
    print("No existen datos duplicados en el DataFrame.")
# Out:
# No existen datos duplicados en el DataFrame.

# %%
# Eliminación de los id
data.drop(['id'], axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# diagnosis                  0
# radius_mean                0
# texture_mean               0
# perimeter_mean             0
# area_mean                  0
# smoothness_mean            0
# compactness_mean           0
# concavity_mean             0
# concave points_mean        0
# symmetry_mean              0
# fractal_dimension_mean     0
# radius_se                  0
# texture_se                 0
# perimeter_se               0
# area_se                    0
# smoothness_se              0
# compactness_se             0
# concavity_se               0
# concave points_se          0
# symmetry_se                0
# fractal_dimension_se       0
# radius_worst               0
# texture_worst              0
# perimeter_worst            0
# area_worst                 0
# smoothness_worst           0
# compactness_worst          0
# concavity_worst            0
# concave points_worst       0
# symmetry_worst             0
# fractal_dimension_worst    0
# dtype: int64

# %%
data['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
X = data.drop(['diagnosis'], axis=1, inplace=False)
X.describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean
# count   569.000000    569.000000      569.000000   569.000000  \
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean
# count       569.000000        569.000000      569.000000           569.000000  \
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
def histograma(datos, titulo='', nombre_ejex=''):
    plt.figure(figsize=(4, 2))
    plt.hist(datos, edgecolor='k', alpha=0.65)
    plt.title(titulo)
    plt.xlabel(nombre_ejex)
    plt.ylabel('Frecuencia')
    plt.show()

for c in X.columns:
    histograma(X[c], c, c)

# %%
def boxplot(datos, coef, titulo=''):
    plt.figure(figsize=(2,4))
    plt.boxplot(datos, whis=coef)
    plt.title(titulo)
    plt.show()

for c in X.columns:
    boxplot(X[c], 3, c)

# %%
for c in X.columns:
    Q1 = X[c].quantile(0.25)
    Q3 = X[c].quantile(0.75)
    IQR = Q3 - Q1
    coef = 3 #3: extremo, 1.5: normales
    limite_inferior = Q1 - coef * IQR
    limite_superior = Q3 + coef * IQR
    valores_atipicos = X[(X[c] < limite_inferior) | (X[c] > limite_superior)]
    print(f"Valores atípicos {c}:")
    pct = (len(valores_atipicos)/len(X))*100
    print(f'{pct:.2f}%')
# Out:
# Valores atípicos radius_mean:
# 0.18%
# Valores atípicos texture_mean:
# 0.18%
# Valores atípicos perimeter_mean:
# 0.00%
# Valores atípicos area_mean:
# 0.88%
# Valores atípicos smoothness_mean:
# 0.18%
# Valores atípicos compactness_mean:
# 0.18%
# Valores atípicos concavity_mean:
# 0.00%
# Valores atípicos concave points_mean:
# 0.00%
# Valores atípicos symmetry_mean:
# 0.18%
# Valores atípicos fractal_dimension_mean:
# 0.70%
# Valores atípicos radius_se:
# 1.23%
# Valores atípicos texture_se:
# 0.70%
# Valores atípicos perimeter_se:
# 2.11%
# Valores atípicos area_se:
# 3.87%
# Valores atípicos smoothness_se:
# 1.23%
# Valores atípicos compactness_se:
# 1.05%
# Valores atípicos concavity_se:
# 1.05%
# Valores atípicos concave points_se:
# 0.53%
# Valores atípicos symmetry_se:
# 1.58%
# Valores atípicos fractal_dimension_se:
# 1.93%
# Valores atípicos radius_worst:
# 0.00%
# Valores atípicos texture_worst:
# 0.00%
# Valores atípicos perimeter_worst:
# 0.18%
# ...

# %%
## Modelos
# Regresión Logística
# Análisis Discriminante
# KNN
# Árboles de Decisión (bagging)
# Random Forest


## Remuestreo
# Validación cruzada
# Boostrap

# %%
train, test = train_test_split(data, test_size=0.2, random_state=42)

# %% [markdown]
# (Hacer tratamiento sobre train)

# %%
X_train, y_train = train.drop(['diagnosis'])

# %%
lr = LogisticRegression()
param_grid_lr = {
    'penalty' : ['l1', 'l2', 'elasticnet'],
    'C': {0.01, 0.1, 1, 10, 100},
    'class_weight' : {'balanced', None}
}
grid_search_lr = GridSearchCV(lr, param_grid_lr, scoring='neg_mean_absolute_percentage_error', cv=5)
grid_search_lr.fit(X_train, y_train)
best_lr = grid_search_lr.best_estimator_
best_params_lr = grid_search_lr.best_params_
